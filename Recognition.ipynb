# %%
import warnings
warnings.simplefilter('ignore')

# %%
import matplotlib.pyplot as plt
from utils import Identification, OpenCV

# %%
def showImage(image, size=(10, 10)):
    _, ax = plt.subplots(figsize = size)
    ax.axis('off')
    ax.imshow(image)

# %%
def showImages(images, lines=4, size=(8, 8)):
    cols = (len(images) / lines) + 1
    fig = plt.figure(figsize=size)
    for i in range(len(images)):
        ax = fig.add_subplot(lines, cols, i+1)
        ax.imshow(images[i])
        ax.axis('off')
    plt.show()

# %%
path = 'data/images/example.jpg'

# %%
photo = OpenCV.getImage(path)
showImage(photo)

# %%
photo, faces = Identification.extractFaces(path)

# %%
showImage(photo, (18, 18))

# %%
# TODO: Align Face
showImages(faces)
