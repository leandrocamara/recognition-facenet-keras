# %%
import warnings
warnings.simplefilter('ignore')

# %%
import matplotlib.pyplot as plt
from utils import Identification, FaceNet
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\leand\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
def showImage(image, size=(10, 10)):
    _, ax = plt.subplots(figsize = size)
    ax.axis('off')
    ax.imshow(image)

# %%
def showImages(images, lines=4, size=(7, 7)):
    cols = (len(images) / lines) + 1
    fig = plt.figure(figsize=size)
    for i in range(len(images)):
        ax = fig.add_subplot(lines, cols, i+1)
        ax.imshow(images[i])
        ax.axis('off')
    plt.show()

# %%
directory = 'data/targets/input'
targets, targetsPhotos = Identification.loadInputFaces(directory)
# Out:
# WARNING:tensorflow:From C:\Users\leand\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
# TODO: Align Face
showImages([photo for _, photo in targetsPhotos.items()], lines=2, size=(12, 12))
showImages([target['face'] for target in targets], lines=2)

# %%
directory = 'data/database/input'
people, peoplePhotos = Identification.loadInputFaces(directory)

# %%
# TODO: Align Face
showImages([photo for _, photo in peoplePhotos.items()], lines=1, size=(12, 12))
showImages([person['face'] for person in people])

# %%
photos = FaceNet.searchFaces(targets, people, peoplePhotos)

# %%
showImages([photo for _, photo in photos.items()], lines=1, size=(32, 32))
